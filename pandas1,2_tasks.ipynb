# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ###`Q-1:` Write a program to create an empty series.

# %%
# code here
empty_series = pd.Series()
print(empty_series)
# Out:
# Series([], dtype: object)

# %% [markdown]
# ###`Q-2:` Write a Pandas program to add, subtract, multiple and divide two Pandas Series.

# %%
# code here
pandas_series1 = pd.Series([1,2,3,4,5])
pandas_series2 = pd.Series([6,7,8,9,10])

print(pandas_series1 + pandas_series2)
print(pandas_series1 - pandas_series2)
print(pandas_series1 * pandas_series2)
print(pandas_series1 / pandas_series2)
# Out:
# 0     7
# 1     9
# 2    11
# 3    13
# 4    15
# dtype: int64
# 0   -5
# 1   -5
# 2   -5
# 3   -5
# 4   -5
# dtype: int64
# 0     6
# 1    14
# 2    24
# 3    36
# 4    50
# dtype: int64
# 0    0.166667
# 1    0.285714
# 2    0.375000
# 3    0.444444
# 4    0.500000
# dtype: float64

# %% [markdown]
# ###`Q-3` Write a Pandas program to compare the elements of the two Pandas Series.
# Sample Series: [2, 4, 6, 8, 10], [1, 3, 5, 7, 10]

# %%
# code here
samp_series1 = pd.Series([2,4,6,8,10])
samp_series2 = pd.Series([1,3,5,7,10])
print(samp_series1 < samp_series2)
print(samp_series1 > samp_series2)
print(samp_series1 >= samp_series2)
print(samp_series1 <= samp_series2)
print(samp_series1 == samp_series2)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# dtype: bool
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# dtype: bool
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# ###`Q-5.`Write a function to change the data type of given a column or a Series. Function takes series and data type as input, returns the converted series.
# ```
# series = pd.Series([1,2,'Python', 2.0, True, 100])
# change to float type data
# ```
# Note: Read about pd.to_numeric()

# %%
# code here
series = pd.Series([1,2,'Python',2.0,True,100])

def type_conversion(pd_series):
  return pd.to_numeric(pd_series,'coerce')

type_conversion(series)
# Out:
# 0      1.0
# 1      2.0
# 2      NaN
# 3      2.0
# 4      1.0
# 5    100.0
# dtype: float64

# %% [markdown]
# Download data - https://drive.google.com/file/d/1LRhXwbEodeWXtzPhJCX0X9Lf_BECzvqb/view?usp=share_link
# All Batsman runs series in IPL 2008 to 2022.
#
# Below questions are based on this data.

# %% [markdown]
# ###`Q-6` Find top 10 most run getter from the series.

# %%
# code here
cricket_runs = pd.read_csv('batsman_runs_series.csv')
cricket_runs = cricket_runs.set_index('batter')['batsman_run']
cricket_runs.sort_values(ascending = False).head(10)
# Out:
# batter
# V Kohli           6634
# S Dhawan          6244
# DA Warner         5883
# RG Sharma         5881
# SK Raina          5536
# AB de Villiers    5181
# CH Gayle          4997
# MS Dhoni          4978
# RV Uthappa        4954
# KD Karthik        4377
# Name: batsman_run, dtype: int64

# %% [markdown]
# ###`Q-7` No of players having runs above 3000

# %%
# code here
print(f'There are {cricket_runs[cricket_runs > 3000].count()} players with runs above 3000' )
cricket_runs[cricket_runs > 3000]
# Out:
# There are 20 players with runs above 3000
# batter
# AB de Villiers    5181
# AM Rahane         4074
# AT Rayudu         4190
# CH Gayle          4997
# DA Warner         5883
# F du Plessis      3403
# G Gambhir         4217
# KA Pollard        3437
# KD Karthik        4377
# KL Rahul          3895
# MK Pandey         3657
# MS Dhoni          4978
# RG Sharma         5881
# RV Uthappa        4954
# S Dhawan          6244
# SK Raina          5536
# SR Watson         3880
# SV Samson         3526
# V Kohli           6634
# YK Pathan         3222
# Name: batsman_run, dtype: int64

# %% [markdown]
# ###`Q-8` No of players having runs above mean value?

# %%
# code here
cricket_runs[cricket_runs>cricket_runs.mean()].count()
# Out:
# np.int64(128)

# %% [markdown]
# Download data - https://drive.google.com/file/d/1QZuZ5bypUInfVvarHACLAi8tXXHvb8xd/view?usp=share_link
#
# file name - items.csv

# %% [markdown]
# ###`Q-9`
#     i. Read `items.csv` making `item_name` as index.
#     ii. Show no of nan values
#     ii. Item price is given in $, so convert it to rupees without currency symbol.
#     iii. Make data type of newly made series as float.
#     iv. Fill nan with mean of the series
#
#
# How csv file looks
#
# ```
# item_name	item_price
# Chips and Fresh Tomato Salsa	$2.39
# Izze	$3.39
# Nantucket Nectar	$3.39
# Chips and Tomatillo-Green Chili Salsa	$2.39
# Chicken Bowl	$16.98
#
# ```

# %%
items_data = pd.read_csv('items.csv')
items_data = items_data.set_index('item_name')['item_price']
print(items_data.isnull().sum()) # 50 null values are present
items_data = pd.to_numeric(items_data.str.replace("$", "", regex=False),errors="coerce") * 91
items_data.fillna(items_data.mean(),inplace=True)
items_data
# Out:
# 50
# item_name
# Chips and Fresh Tomato Salsa              217.49
# Izze                                      308.49
# Nantucket Nectar                          308.49
# Chips and Tomatillo-Green Chili Salsa     217.49
# Chicken Bowl                             1545.18
#                                           ...
# Steak Burrito                            1069.25
# Steak Burrito                            1069.25
# Chicken Salad Bowl                       1023.75
# Chicken Salad Bowl                        796.25
# Chicken Salad Bowl                        796.25
# Name: item_price, Length: 4622, dtype: float64

# %% [markdown]
# ###`Q-10`:
#     i. Find mean price
#     ii. Find 30th and 6th percentile value
#     iii. Plot Histogram on price with bin size 50
#     iv. No of items price lies between [1000 to 2000]

# %%
# code here
print(round(items_data.mean(),2))
print(items_data.quantile([0.30,0.6]))
items_data.plot(kind="hist", bins=50)
items_data[items_data.between(1000,2000)].count()
# Out:
# 0.3    404.95
# 0.6    796.25
# Name: item_price, dtype: float64
# np.int64(979)

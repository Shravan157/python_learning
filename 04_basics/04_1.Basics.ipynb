# %%
## Functions in python
"""

1. Introduction to functions
2. Defining functions
3. Calling functions'
4. Function Parameters
5. Default Parameters
6. Variable-length Arguments
7. Return Statement

"""

# %%
"""
Definition of Function
A function is a block of code that perform a specific task. Function help in organizing code , reusing code and
improving readability

"""

# %%
## Syntax of the Function

def function_name(parameters):
    """ DocString : To understand what this function does. """
    ## Function body
    return result

# %%
## simple example of function

def is_even_or_odd(num):
    """ Whether the given number is even or odd. """
    if num>0:
        if num%2==0:
            print(f"{num} is Even")
        else:
            print(f"{num} is Odd")
    else:
        print(f"{num} is Negative")



is_even_or_odd(5)
is_even_or_odd(6)
is_even_or_odd(7)
# Out:
# 5 is Odd
# 6 is Even
# 7 is Odd

# %%
## working with multiple parameters

def add(num1 , num2):
    return num1+num2

result = add(2,5)
print(result)
# Out:
# 7

# %%
def greet(name):
    print(f"Hello {name} welcome to function")

greet("shravan")
# Out:
# Hello shravan welcome to function

# %%
# In case if the user does not pass the value in function, then  we can set a default value
# If the no parameter is entered then the default value will be executed
def greet(name = "Guest"):
    print(f"Hello {name} welcome to function")

greet() # we are not giving any parameter when we are calling the function 
greet("shravan")
# Out:
# Hello Guest welcome to function
# Hello shravan welcome to function

# %%
## Variable Length arguments
## Positional and keywords arguments
## If there are multiple arguments to be entered in the function, then instead of mentioning all of them we can simply use
## *args
def print_numbers(*args):
    """ Positional arguments : use *args , which has multiple arguments """
    for i in args:
        print(i)

print_numbers(1,2,3,"shravan",5,6) # we can add as many argument as we need
# Out:
# 1
# 2
# 3
# shravan
# 5
# 6

# %%
## Keywords argument: it is denoted by ** , and all the parameters will be in form of key value pairs


def print_detail(**kwargs):
    for key,value in kwargs.items():
        print(f"{key}:{value}")

print_detail(Name = "Shravan" , City = "Mumbai" , Age = 20 , Course = "CSE(AIML)")
# Out:
# Name:Shravan
# City:Mumbai
# Age:20
# Course:CSE(AIML)

# %%
## Combining both the Positional Argument and keyword argument in a single function
def print_detail(*args ,**kwargs):
    for val in args:
        print(f"Positional Argument : {val}")
    for key,value in kwargs.items():
        print(f"{key}:{value}")

print_detail(1,2,4,5,6,Name = "Shravan" , relationship_status = "single" , Age = 20 , Course = "CSE(AIML)" )
# Out:
# Positional Argument : 1
# Positional Argument : 2
# Positional Argument : 4
# Positional Argument : 5
# Positional Argument : 6
# Name:Shravan
# relationship_status:single
# Age:20
# Course:CSE(AIML)

# %%
## return statement

def multiply(num1,num2):

    return num1*num2

print(multiply(1,2))
# Out:
# 2

# %%
# we can return multiple parameters
def multiply(num1,num2):
    return num1*num2,num1,num2

print(multiply(1,2))
# Out:
# (2, 1, 2)

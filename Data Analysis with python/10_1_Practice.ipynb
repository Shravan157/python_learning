# %%
# NumPy Fundamentals Assignment
# Complete all questions below. Test your code to ensure it works correctly.

import numpy as np

print("="*60)
print("SECTION 1: Array Creation (10 questions)")
print("="*60)

# Q1. Create a 1D array with numbers from 10 to 50 (inclusive)
q1 = np.arange(10,51)  # Your code here
print("Q1:", q1)

# Q2. Create a 4x5 matrix filled with zeros
q2 = np.zeros((4,5))  # Your code here
print("Q2:\n", q2)

# Q3. Create a 3x3 identity matrix
q3 = np.identity(3)  # Your code here
print("Q3:\n", q3)

# Q4. Create an array with 15 evenly spaced values between 0 and 100
q4 = np.linspace(0,101,15)  # Your code here
print("Q4:", q4)

# Q5. Create a 5x6 matrix with random values between 0 and 1
q5 = np.random.random((5,6))  # Your code here
print("Q5:\n", q5)

# Q6. Create a 1D array of even numbers from 2 to 20 using arange
q6 = np.arange(2,21,2)  # Your code here
print("Q6:", q6)

# Q7. Create a 3x4 matrix with values from 1 to 12, then reshape it to 2x6
q7 = np.arange(1,13).reshape((2,6))  # Your code here
print("Q7:\n", q7)

# Q8. Create a 2x3x4 3D array with values from 0 to 23
q8 = np.arange(0,24).reshape(2,3,4)  # Your code here
print("Q8:\n", q8)

# Q9. Create a 4x4 matrix of ones and convert it to integer type
q9 = np.ones((4,4)).astype(dtype=int)  # Your code here
print("Q9:\n", q9)

# Q10. Create a copy of the array [1,2,3,4,5] and multiply the copy by 10
original = np.array([1,2,3,4,5])
q10 = np.copy(original)*10  # Your code here
print("Q10 - Original:", original, "Copy:", q10)

print("\n" + "="*60)
print("SECTION 2: Array Attributes (5 questions)")
print("="*60)

test_array = np.arange(24).reshape(2,3,4)

# Q11. Find the shape of test_array
q11 = np.shape(test_array)  # Your code here
print("Q11:", q11)

# Q12. Find the number of dimensions of test_array
q12 = np.ndim(test_array)  # Your code here
print("Q12:", q12)

# Q13. Find the total number of elements in test_array
q13 = np.size(test_array)  # Your code here
print("Q13:", q13)

# Q14. Find the data type of test_array
q14 = np.dtype(test_array)  # Your code here
print("Q14:", q14)

# Q15. Find the memory size (in bytes) of each element in test_array
q15 = test_array.itemsize  # Your code here
print("Q15:", q15)

print("\n" + "="*60)
print("SECTION 3: Indexing and Slicing (10 questions)")
print("="*60)

arr_2d = np.arange(20).reshape(4,5)
arr_3d = np.arange(27).reshape(3,3,3)

print("2D Array:\n", arr_2d)
print("\n3D Array:\n", arr_3d)

# Q16. Extract element at row 2, column 3 from arr_2d
q16 = arr_2d[1,2] # Your code here
print("\nQ16:", q16)

# Q17. Extract the last row of arr_2d
q17 = arr_2d[-1]  # Your code here
print("Q17:", q17)

# Q18. Extract the first column of arr_2d
q18 = arr_2d[:,0]  # Your code here
print("Q18:", q18)

# Q19. Extract elements [6,7,11,12] from arr_2d (rows 1-2, columns 1-2)
q19 = arr_2d[1:3,1:3]  # Your code here
print("Q19:\n", q19)

# Q20. Extract all even-indexed rows and odd-indexed columns from arr_2d
q20 = arr_2d[0::2,1::2]  # Your code here
print("Q20:\n", q20)

# Q21. From arr_3d, extract the middle 2D array (second matrix)
q21 = arr_3d[1]  # Your code here
print("Q21:\n", q21)

# Q22. From arr_3d, extract element at position [1,2,0]
# arr_3d[ depth ][ row ][ column ]
q22 = arr_3d[1,2,0]  # Your code here
print("Q22:", q22)

# Q23. From arr_3d, extract the last row of the last 2D array
q23 = arr_3d[2,-1,:]  # Your code here
print("Q23:", q23)

# Q24. From arr_3d, extract all elements in the middle column across all matrices
q24 = arr_3d[:,:,1]  # Your code here
print("Q24:\n", q24)

# Q25. Reverse the order of elements in arr_2d's first row
q25 = arr_2d[0,::-1]  # Your code here
print("Q25:", q25)

print("\n" + "="*60)
print("SECTION 4: Array Operations (10 questions)")
print("="*60)

a = np.array([[1,2,3],[4,5,6]])
b = np.array([[7,8,9],[10,11,12]])

# Q26. Add 10 to every element in array 'a'
q26 = a+10  # Your code here
print("Q26:\n", q26)

# Q27. Square every element in array 'b'
q27 = b**2  # Your code here
print("Q27:\n", q27)

# Q28. Add arrays 'a' and 'b' element-wise
q28 = a+b  # Your code here
print("Q28:\n", q28)

# Q29. Multiply arrays 'a' and 'b' element-wise
q29 = a*b  # Your code here
print("Q29:\n", q29)

# Q30. Create a boolean array showing which elements in 'a' are greater than 3
q30 = a>3  # Your code here
print("Q30:\n", q30)

# Q31. Find the dot product of arrays 'a' (2x3) and 'b.T' (3x2)
q31 = np.dot(a,b.T)  # Your code here
print("Q31:\n", q31)

# Q32. Calculate the square root of all elements in array 'a'
q32 = np.sqrt(a)  # Your code here
print("Q32:\n", q32)

# Q33. Round array 'a' divided by 3 to 2 decimal places
q33 = np.round(a/3,2)  # Your code here
print("Q33:\n", q33)

# Q34. Find where elements in 'b' are divisible by 2 (use modulus)
q34 = np.mod(b, 2) == 0
print("Q34:\n", q34)

# Q35. Raise array 'a' to the power of 2 and subtract 1
q35 = np.pow(a,2) - 1  # Your code here
print("Q35:\n", q35)

print("\n" + "="*60)
print("SECTION 5: Array Functions (10 questions)")
print("="*60)

data = np.array([[15, 23, 8], [42, 16, 31], [9, 54, 12]])
print("Data array:\n", data)

# Q36. Find the maximum value in the entire array
q36 = np.max(data)  # Your code here
print("\nQ36:", q36)

# Q37. Find the minimum value in each column
q37 = np.min(data, axis=0)
print("Q37:", q37)


# Q38. Find the sum of each row
q38 = np.sum(data,axis=1)  # Your code here
print("Q38:", q38)

# Q39. Calculate the mean of the entire array
q39 = np.mean(data)  # Your code here
print("Q39:", q39)

# Q40. Calculate the median of each column
q40 = np.median(data,axis=0)  # Your code here
print("Q40:", q40)

# Q41. Calculate the standard deviation of each row
q41 = np.std(data,axis=1)  # Your code here
print("Q41:", q41)

# Q42. Find the product of all elements in the array
q42 = np.prod(data)  # Your code here
print("Q42:", q42)

# Q43. Calculate the variance of the entire array
q43 = np.var(data)  # Your code here
print("Q43:", q43)

# Q44. Find the maximum value in each row
q44 = np.max(data,axis=1)  # Your code here
print("Q44:", q44)

# Q45. Calculate the cumulative sum of the flattened array
q45 = np.cumsum(data)  # Your code here
print("Q45:", q45)

print("\n" + "="*60)
print("SECTION 6: Stacking and Reshaping (5 questions)")
print("="*60)

x = np.arange(6).reshape(2,3)
y = np.arange(6,12).reshape(2,3)

print("Array x:\n", x)
print("Array y:\n", y)

# Q46. Stack x and y horizontally
q46 = np.hstack((x,y))  # Your code here
print("\nQ46:\n", q46)

# Q47. Stack x and y vertically
q47 = np.vstack((x,y))  # Your code here
print("Q47:\n", q47)

# Q48. Flatten array x into a 1D array using ravel
q48 = np.ravel(x)  # Your code here
print("Q48:", q48)

# Q49. Transpose array x
q49 = x.T  # Your code here
print("Q49:\n", q49)

# Q50. Create array from 0-11, reshape to 3x4, then split horizontally into 2 parts
arr_split = np.arange(12).reshape(3,4)
q50_left, q50_right = np.hsplit(arr_split,2)  # Your code here
print("Q50 Left:\n", q50_left)
print("Q50 Right:\n", q50_right)

print("\n" + "="*60)
print("BONUS CHALLENGES (5 questions)")
print("="*60)

# B1. Create a 5x5 matrix with values 1,2,3,4 just below the diagonal
#np.diag([1, 2, 3, 4], k=-1) creates a matrix with the values 1,2,3,4 on the diagonal that is one position below the main diagonal
b1 = np.diag([1,2,3,4],k=-1)  # Your code here
print("B1:\n", b1)

# B2. Create a 8x8 checkerboard pattern (alternating 0s and 1s)
b2 = np.zeros((8, 8), dtype=int)
b2[::2, 1::2] = 1  # Set odd columns in even rows to 1
b2[1::2, ::2] = 1  # Set even columns in odd rows to 1
print("B2:\n", b2)


# B3. Normalize the following array (subtract mean, divide by std deviation)
arr_norm = np.array([10, 20, 30, 40, 50])
b3 = (arr_norm - np.mean(arr_norm)) / np.std(arr_norm)  # Your code here
print("B3:", b3)

# B4. Create a 4x4 matrix and extract only the border elements
border_arr = np.arange(16).reshape(4,4)
print(border_arr)
b4 = border_arr[::3,::3]  # Your code here
print("B4:", b4)

# B5. Create two arrays and find their common elements
arr1 = np.array([1,2,3,4,5])
arr2 = np.array([4,5,6,7,8])
b5 = np.intersect1d(arr1,arr2)  # Your code here
print("B5:", b5)
# b5 = [] # Alternate answer
# for i in arr1:
#     if i in arr2:
#         b5.append(i)
# print("B5:", b5)  # [4, 5]

print("\n" + "="*60)
print("Assignment Complete! Check your answers.")
print("="*60)

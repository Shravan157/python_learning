# %%
from mistune.plugins.def_list import TRIM_RE

"""

Operators in python
1. Introduction to operators
2. Arithmetic operators
   Addition , Subtraction , Multiplication , Division , Modulus , Exponentiation , Floor Division

3. Comparison operators
   Equal to , Not equal to , Greater than , Less than , Greater than or equal to , Less than or equal to

4. Logical operators
   And , Or , Not


"""

# %%
a = 5
b = 4

add_result = a + b
mult_result = a * b
div_result = a / b
mod_result = a % b
exp_result = a ** b
floor_div_result = a // b
diff_result = a - b

print(add_result)
print(mult_result)
print(div_result)
print(mod_result)
print(exp_result)
print(floor_div_result)
print(diff_result)

# %%
# Comparison operators
a = 10
b = 10

print(a!=b)
print(a==b)

str1 = "Shravan"
str2 = "shravan"

print(str1 == str2)
# Out:
# False
# True
# False

# %%
num1 = 25
num2 = 5

print(num1>num2)
print(num1>=num2)
print(num1<=num2)
# Out:
# True
# True
# False

# %%
#Logical operators
# And , OR and NOT

x = True
y = True
print(x and y) # When both true then only true

## OR operator

a = False
b = True
print(a or b) # it is the addition operation

## Not operator
N = False
print(not N)
# Out:
# True
# True
# True
